# %%
from re import A
print("-----Student Data-----")
name=input("enter student name")
name=input("enter father name")
Roll number = int(inpt("enter your roll number"))
print("-----Marks-----")
maths=float(input("enter marks"))
computer=int(input("enter marks"))
chemistry=int(input("enter marks"))
physics=float(input("enter marks"))
urdu=int(input("enter marks"))
total marks=maths+computer+chemistry+physics+urdu
Percentage=(total marks/500)*100
if percentage is <=80:
grade is 'A+'
elif percentage is <=70:
grade is 'A'
elif percentage is <=60:
grade is 'B'
elif percentage is <=50:
grade is 'C'
elif percentage is <=40:
grade is 'D'
else:
  grade is 'Fail'
  print("\n------Marksheet------")
  print("Student name",name)
  print("father name",fathr name)
  print("maths",maths)
  print("computer",computer)
  print("chemistry",chemistry)
  print("physics",physics)
  print("urdu",urdu)
  print("total marks",total marks)
  print("percentage",percentage)
  print("grade,grade")
# Out:
#   File "<ipython-input-1-58995e16ad11>", line 4
#     Roll number = int(inpt("enter your roll number"))
#          ^
# SyntaxError: invalid syntax
